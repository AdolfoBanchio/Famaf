# %%
import random as rd
from math import sqrt,pi

# %%
def cauchy():
    while True:
        u=rd.random()
        v=rd.random()
        if u**2 + v**2 < sqrt(1/pi):
            return v/u

# %%
cauchy()
